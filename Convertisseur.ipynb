# %% [markdown]
# # TP3 - CONVERTISSEUR PYTHON

# %% [markdown]
# ## 1 . DECIMAL - BINAIRE

# %% [markdown]
# saisir un entier n compris entre 0 et 255
# i=7
# a=""
# tant que i>=0 faire
# ---------si n - (2 exposant i) >= 0 alors
# ------------a = a + '1'
# ------------n = n - (2 exposant i)
# ---------sinon
# --------------a = a + '0'
# ----------i = i - 1
# afficher a

# %% [markdown]
# ## 2 .  BINAIRE - DECIMAL

# %% [markdown]
# # TP3 - CONVERTISSEUR PYTHON

# %% [markdown]
# ## 1 . DECIMAL - BINAIRE

# %% [markdown]
# ![ex1tp4.PNG](attachment:ex1tp4.PNG)

# %% [markdown]
# ## 2 .  BINAIRE - DECIMAL

# %% [markdown]
# ![ex2tp4.PNG](attachment:ex2tp4.PNG)
